# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchvision import datasets, transforms
import random
import numpy as np
import matplotlib.pyplot as plt
import byzfl
import torch.nn.functional as F
import copy

# ------------------------------------------------------------------------------
# Fonctions utilitaires (inchangées)
def merge_intervals(intervals):
    if not intervals:
        return []
    intervals.sort()
    merged = [intervals[0]]
    for current in intervals[1:]:
        last = merged[-1]
        if current[0] <= last[1]:
            merged[-1] = (last[0], max(last[1], current[1]))
        else:
            merged.append(current)
    return merged

def generate_gaussian_availability(total_time_steps, worker_id, num_workers,
                                   std_dev_ratio=0.08, min_processing_time=3,
                                   smoothing_window=10):
    """
    - Moins de pics (3 max), chacun avec intensité fixe = 1
    - Durées plus longues (3–5 × min_processing_time)
    - Après fusion, on dilate (smoothing_window) pour lisser les petits trous
    """
    peak_means = [0.2, 0.5, 0.8]
    std_dev = int(std_dev_ratio * total_time_steps)
    availability_periods = []
    for mean_ratio in peak_means:
        mean = int(mean_ratio * total_time_steps)
        # on fixe une seule intensité
        start_time = int(np.random.normal(loc=mean, scale=std_dev))
        start_time = max(0, min(start_time, total_time_steps - min_processing_time*3))
        # durée plus longue
        duration = random.randint(min_processing_time*3,
                                  min(min_processing_time*5, total_time_steps - start_time))
        end_time = start_time + duration
        availability_periods.append((start_time, end_time))

    # fusion des intervalles
    merged = merge_intervals(availability_periods)

    # dilation (smoothing) : on élargit chaque intervalle de +/- smoothing_window
    smoothed = []
    for s, e in merged:
        s2 = max(0, s - smoothing_window)
        e2 = min(total_time_steps, e + smoothing_window)
        smoothed.append((s2, e2))

    return merge_intervals(smoothed)


def generate_gaussian_byzantine_availability(
    total_time_steps, worker_id, num_workers,
    std_dev_ratio=0.05, min_processing_time=3,
    smoothing_window=10  # beaucoup plus large pour combler les trous
):
    off_peak_means = [0.1, 0.9]
    std_dev = int(std_dev_ratio * total_time_steps)
    availability_periods = []
    for mean_ratio in off_peak_means:
        mean = int(mean_ratio * total_time_steps)
        start = int(np.random.normal(loc=mean, scale=std_dev))
        start = max(0, min(start, total_time_steps - min_processing_time*4))
        # on force des durées très longues
        duration = random.randint(
            min_processing_time*4,
            min(min_processing_time*8, total_time_steps - start)
        )
        availability_periods.append((start, start + duration))

    # fusion + dilution (lissage)
    merged = merge_intervals(availability_periods)
    smoothed = []
    for s, e in merged:
        s2 = max(0, s - smoothing_window)
        e2 = min(total_time_steps, e + smoothing_window)
        smoothed.append((s2, e2))

    return merge_intervals(smoothed)

# ------------------------------------------------------------------------------
# Modèle
class LeNetLike(nn.Module):
    def __init__(self):
        super(LeNetLike, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64*7*7, 128)
        self.dropout = nn.Dropout(0.25)
        self.fc2 = nn.Linear(128, 10)
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64*7*7)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# ------------------------------------------------------------------------------
# Gestionnaire de batch
class BatchManager:
    def __init__(self, dataset, batch_size):
        self.dataset = dataset
        self.batch_size = batch_size
        self.indices = list(range(len(dataset)))
        random.shuffle(self.indices)
        self.sampler = SubsetRandomSampler(self.indices)
        self.loader = iter(DataLoader(self.dataset, batch_size=self.batch_size, sampler=self.sampler))
    def get_next_batch(self):
        try:
            return next(self.loader)
        except StopIteration:
            random.shuffle(self.indices)
            self.sampler = SubsetRandomSampler(self.indices)
            self.loader = iter(DataLoader(self.dataset, batch_size=self.batch_size, sampler=self.sampler))
            return next(self.loader)

# ------------------------------------------------------------------------------
# Workers
class Worker:
    def __init__(self, model, device, worker_id, availability_periods, processing_time):
        self.is_byzantine = False  # Worker honnête par défaut
        self.device = device
        self.worker_id = worker_id
        self.availability_periods = availability_periods
        self.processing_time = processing_time
        self.model = model.to(device)
        self.criterion = nn.CrossEntropyLoss()
        self.finish_time = None
        self.current_batch_info = None  # (batch_id, mini_batch_idx)
    def is_available(self, current_time):
        for start, end in self.availability_periods:
            if start <= current_time < end:
                if self.finish_time is None or current_time >= self.finish_time:
                    return (current_time + self.processing_time) <= end
        return False
    def start_computation(self, current_time, batch_info, data, targets):
        if self.current_batch_info is None or self.current_batch_info != batch_info:
            self.current_batch_info = batch_info
            self.finish_time = current_time + self.processing_time
            return self.compute_gradient(data, targets)
        return None
    def has_finished(self, current_time):
        return self.finish_time == current_time
    def compute_gradient(self, data, targets):
        data, targets = data.to(self.device), targets.to(self.device)
        self.model.zero_grad()
        outputs = self.model(data)
        loss = self.criterion(outputs, targets)
        loss.backward()
        gradients = {name: param.grad.detach().clone() for name, param in self.model.named_parameters()}
        return gradients, self.current_batch_info
    def update_model(self, model_state_dict):
        self.model.load_state_dict(model_state_dict)

class ByzantineWorker(Worker):
    def __init__(self, model, device, worker_id, availability_periods, processing_time):
        super().__init__(model, device, worker_id, availability_periods, processing_time)
        self.is_byzantine = True
    def compute_gradient(self, data, targets):
        corrupted_gradients = {}
        for name, param in self.model.named_parameters():
            corrupted_gradients[name] = torch.full_like(param, 1e6)
        return corrupted_gradients, self.current_batch_info

# ------------------------------------------------------------------------------
# Server
class Server:
    def __init__(self, dataset, batch_size=64, mini_batch_size=16, lr=0.005, verbose=False,
                 aggregation_strategy='trimmed_mean', f=0, preagg=None):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = LeNetLike().to(self.device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.batch_manager = BatchManager(dataset, batch_size)
        self.mini_batch_size = mini_batch_size
        self.current_complete_batch = None
        self.current_batch_id = 0
        self.received_gradients = {}  # mini_idx -> gradient ou liste jusqu'au vote
        self.verbose = verbose
        self.aggregation_strategy = aggregation_strategy
        self.f = f
        self.preagg = preagg
        self.update_count = 0
        self.total_raw_compute_time = 0
        self.total_useful_compute_time = 0
        self.total_waste_compute_time = 0
        # Accumulateur de temps utile pour le full batch courant (issu des contributions gagnantes)
        self.current_full_batch_compute_time = 0

    def get_new_complete_batch(self, current_time):
        data, targets = self.batch_manager.get_next_batch()
        self.current_complete_batch = (data, targets)
        self.current_batch_id += 1
        # Réinitialiser l'accumulateur du full batch courant
        self.current_full_batch_compute_time = 0
        mini_batches = []
        num_samples = data.size(0)
        for i in range(0, num_samples, self.mini_batch_size):
            mini_data = data[i : i+self.mini_batch_size]
            mini_targets = targets[i : i+self.mini_batch_size]
            mini_batches.append((mini_data, mini_targets))
        self.current_mini_batches = {i: mini_batches[i] for i in range(len(mini_batches))}
        self.received_gradients = {}
        if self.verbose:
            print(f"[Temps {current_time}] Full batch {self.current_batch_id} préparé avec {len(mini_batches)} mini-batches.")

    def register_gradient(self, gradients, batch_info, worker_id, current_time, worker_processing_time, is_byzantine=False):
        batch_id, mini_idx = batch_info
        if batch_id != self.current_batch_id:
            return
        if mini_idx in self.received_gradients and isinstance(self.received_gradients[mini_idx], dict):
            return
        # Comptabilisation du temps brut
        self.total_raw_compute_time += worker_processing_time
        if mini_idx not in self.received_gradients:
            self.received_gradients[mini_idx] = []
        self.received_gradients[mini_idx].append((gradients, worker_id, worker_processing_time))
        if self.verbose:
            extra = " (Byzantin)" if is_byzantine else ""
            print(f"[Temps {current_time}] Gradient reçu pour mini-batch {mini_idx} par worker {worker_id}{extra} (temps: {worker_processing_time}).")
        # Vote : ici, k=4 et t=(k//2)+1
        k = 1
        t = (k // 2) + 1
        if len(self.received_gradients[mini_idx]) == k:
            grad_tuples = self.received_gradients[mini_idx]
            grads_list = [item[0] for item in grad_tuples]
            if self._vote_majority_equality(grads_list, t):
                accepted_gradient = self._select_majority_gradient(grads_list, t)
                # Identifier le worker gagnant dont le gradient est égal à accepted_gradient
                accepted_index = None
                for idx, (g, wid, ptime) in enumerate(grad_tuples):
                    if self._gradients_are_equal(g, accepted_gradient):
                        accepted_index = idx
                        break
                if accepted_index is not None:
                    accepted_time = grad_tuples[accepted_index][2]
                    # Les autres contributions vont dans waste computing time
                    other_time = sum(item[2] for i, item in enumerate(grad_tuples) if i != accepted_index)
                    # Seul le temps du worker gagnant est ajouté comme temps utile pour le full batch
                    self.current_full_batch_compute_time += accepted_time
                    self.total_waste_compute_time += other_time
                    self.received_gradients[mini_idx] = accepted_gradient
                    if self.verbose:
                        print(f"[Temps {current_time}] Mini-batch {mini_idx} accepté : temps utile = {accepted_time}, temps gaspillé = {other_time}.")
                else:
                    total_time = sum(item[2] for item in grad_tuples)
                    self.total_waste_compute_time += total_time
                    if self.verbose:
                        print(f"[Temps {current_time}] Erreur dans le vote pour mini-batch {mini_idx}. Temps total gaspillé : {total_time}.")
                    del self.received_gradients[mini_idx]
            else:
                total_time = sum(item[2] for item in grad_tuples)
                self.total_waste_compute_time += total_time
                if self.verbose:
                    print(f"[Temps {current_time}] Rejet du mini-batch {mini_idx} par vote majoritaire. Temps gaspillé : {total_time}.")
                del self.received_gradients[mini_idx]

    def _gradients_are_equal(self, grad1, grad2, rtol=1e-3, atol=1e-8):
        for key in grad1:
            if not torch.allclose(grad1[key], grad2[key], rtol=rtol, atol=atol):
                return False
        return True

    def _vote_majority_equality(self, grads, t):
        counts = [0] * len(grads)
        for i in range(len(grads)):
            for j in range(len(grads)):
                if self._gradients_are_equal(grads[i], grads[j]):
                    counts[i] += 1
        return max(counts) >= t

    def _select_majority_gradient(self, grads, t):
        for i, g in enumerate(grads):
            cnt = sum(1 for other in grads if self._gradients_are_equal(g, other))
            if cnt >= t:
                return g
        aggregated = {}
        for key in grads[0]:
            aggregated[key] = torch.mean(torch.stack([g[key] for g in grads]), dim=0)
        return aggregated

    def aggregate_and_update(self):
        if len(self.received_gradients) != len(self.current_mini_batches):
            if self.verbose:
                print("Attention : certains mini-batches ne sont pas traités.")
            return False
        for idx in self.current_mini_batches:
            if idx not in self.received_gradients or not isinstance(self.received_gradients[idx], dict):
                if self.verbose:
                    print(f"Mini-batch {idx} n'a pas encore un gradient accepté.")
                return False
        aggregated_gradients = {}
        self.f = 4
        if self.preagg == "NNM":
            preaggregator = byzfl.NNM(f=self.f)
        elif self.preagg == "Bucketing":
            preaggregator = byzfl.Bucketing(s=1)
        elif self.preagg == "ARC":
            preaggregator = byzfl.ARC(f=self.f)
        else:
            preaggregator = None
        for name, param in self.model.named_parameters():
            grads = [self.received_gradients[idx][name] for idx in self.current_mini_batches]
            grads_tensor = torch.stack(grads)
            original_shape = grads_tensor.shape[1:]
            grads_tensor_flat = grads_tensor.view(grads_tensor.size(0), -1)
            n = grads_tensor_flat.shape[0]
            effective_f = max(self.f, (n // 2) - 1)
            if preaggregator is not None:
                try:
                    preagg_flat = preaggregator(grads_tensor_flat)
                except Exception as e:
                    print(f"Erreur de pré-agrégation ({self.preagg}): {e}")
                    preagg_flat = grads_tensor_flat
            else:
                preagg_flat = grads_tensor_flat
            if self.aggregation_strategy == "trimmed_mean":
                aggregator = byzfl.TrMean(f=effective_f)
            elif self.aggregation_strategy == "multi_krum":
                aggregator = byzfl.MultiKrum(f=effective_f)
            elif self.aggregation_strategy == "geometric_median":
                aggregator = byzfl.GeometricMedian()
            elif self.aggregation_strategy == "average":
                aggregator = byzfl.Average()
            elif self.aggregation_strategy == "meamed":
                aggregator = byzfl.Meamed(f=effective_f)
            else:
                raise ValueError(f"Stratégie d’agrégation inconnue : {self.aggregation_strategy}")
            agg_flat = aggregator(preagg_flat)
            aggregated_gradients[name] = agg_flat.view(original_shape)
        self.optimizer.zero_grad()
        for name, param in self.model.named_parameters():
            param.grad = aggregated_gradients[name]
        self.optimizer.step()
        if self.verbose:
            print(f"Modèle mis à jour avec le full batch {self.current_batch_id}.")
        return True

    def evaluate(self, test_loader):
        self.model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, targets in test_loader:
                data, targets = data.to(self.device), targets.to(self.device)
                outputs = self.model(data)
                _, predicted = torch.max(outputs.data, 1)
                total += targets.size(0)
                correct += (predicted == targets).sum().item()
        return 100 * correct / total

    def report_compute_metrics(self):
        total = self.total_raw_compute_time
        useful = self.total_useful_compute_time
        waste = self.total_waste_compute_time
        waste_rate = 100 * waste / total if total > 0 else 0
        print("\n📊 Rapport de temps de calcul :")
        print(f"- Temps brut total : {total}")
        print(f"- Temps utile        : {useful}")
        print(f"- Temps gaspillé     : {waste}")
        print(f"- Taux de gaspillage : {waste_rate:.2f}%")
        categories = ['Utilisé', 'Gaspillé']
        times = [useful, waste]
        plt.figure(figsize=(8,6))
        bars = plt.bar(categories, times)
        plt.title("Répartition du temps de calcul")
        plt.ylabel("Temps cumulé")
        plt.ylim(0, total*1.1)
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x()+bar.get_width()/2.0, height+total*0.02, f'{height:.1f}',
                     ha='center', va='bottom', fontsize=12)
        plt.show()

    def advance_decision(self, p1, p2, p3, sp):
        if p1 == p2 == p3:
            return "rollback"
        if p1 > sp and p2 > p1 and p3 > sp:
            return "accept"
        elif p1 > sp and p2 <= p1 and p3 >= p1:
            return "accept"
        elif p1 <= sp and p2 > sp and p3 > p2:
            return "accept"
        elif p1 <= sp and p2 > p1 and p2 > sp and p3 < p2 and p3 > sp:
            return "accept"
        elif p1 <= sp and p2 <= p1 and p3 > sp:
            return "accept"
        else:
            return "rollback"

# ------------------------------------------------------------------------------
# Création des workers
# Ici, on ne conserve plus une liste fixe d'IDs byzantins, mais on la calcule à chaque cycle.
def create_workers(num_worker, byzantine_indices_cycle, steps_per_cycle, server):
    workers = []
    for i in range(1, num_worker+1):
        processing_time = random.randint(2,5)
        if i in byzantine_indices_cycle:
            availability = generate_gaussian_byzantine_availability(steps_per_cycle, worker_id=i,
                                                                     num_workers=num_worker, min_processing_time=processing_time)
            workers.append(ByzantineWorker(server.model, server.device, i, availability, processing_time))
        else:
            availability = generate_gaussian_availability(steps_per_cycle, worker_id=i,
                                                          num_workers=num_worker, min_processing_time=processing_time)
            workers.append(Worker(server.model, server.device, i, availability, processing_time))
    return workers

# ------------------------------------------------------------------------------
# Simulateur Discret avec stratégie safe-point
class SafePointSimulator:
    def __init__(self, server, workers, test_loader, total_time_steps=1000, group_size=3):
        self.server = server
        self.workers = workers
        self.test_loader = test_loader
        self.total_time_steps = total_time_steps
        self.global_time = 0
        self.in_progress_workers = []
        self.group_size = group_size  # Nombre de full batches avant décision
        self.server.get_new_complete_batch(self.global_time)

    def run(self, verbose=False, eval_interval=10):
        # Sauvegarde initiale du safe point
        self.plot_worker_availability()
        safe_model = copy.deepcopy(self.server.model.state_dict())
        safe_optimizer = copy.deepcopy(self.server.optimizer.state_dict())
        safe_acc = self.server.evaluate(self.test_loader)
        print(f"SafePoint initial - Accuracy: {safe_acc:.2f}%")
        
        group_updates = []        # Accuracies des full batches du groupe
        group_compute_times = []  # Temps utile (contribution gagnante) par full batch
        group_decision_list = []  # (index du groupe, décision, computing time totale utile du groupe)
        group_batch_count = 0
        group_idx = 0  # Index du groupe
        
        accuracy_over_time = []
        time_points = []
        k = 1  # Nombre de workers par mini-batch
        
        while self.global_time < self.total_time_steps:
            # Traitement des workers terminés
            finished_workers = []
            for worker in self.in_progress_workers:
                if worker.has_finished(self.global_time):
                    mini_idx = worker.current_batch_info[1]
                    gradients, batch_info = worker.compute_gradient(*self.server.current_mini_batches[mini_idx])
                    self.server.register_gradient(gradients, batch_info, worker.worker_id,
                                                  self.global_time, worker.processing_time, worker.is_byzantine)
                    finished_workers.append(worker)
            for worker in finished_workers:
                self.in_progress_workers.remove(worker)
                worker.current_batch_info = None

            # Vérifier si tous les mini-batches ont fourni leurs gradients
            if len(self.server.received_gradients) == len(self.server.current_mini_batches):
                if self.server.aggregate_and_update():
                    self.server.update_count += 1
                    acc = self.server.evaluate(self.test_loader)
                    print(f"Temps ({self.global_time}) Full batch {self.server.current_batch_id} traité — Performance = {acc}%")
                    group_updates.append(acc)
                    current_batch_compute_time = self.server.current_full_batch_compute_time
                    group_compute_times.append(current_batch_compute_time)
                    group_batch_count += 1

                    self.server.get_new_complete_batch(self.global_time)
                    self.in_progress_workers = []
                    
                    if group_batch_count == self.group_size:
                        decision = self.server.advance_decision(group_updates[0], group_updates[1],
                                                                group_updates[2], safe_acc)
                        group_total_time = sum(group_compute_times)
                        if decision == "accept":
                            print("Mises à jour du groupe acceptées. Nouveau safe point établi.")
                            safe_model = copy.deepcopy(self.server.model.state_dict())
                            safe_optimizer = copy.deepcopy(self.server.optimizer.state_dict())
                            safe_acc = group_updates[2]
                            self.server.total_useful_compute_time += group_total_time
                            group_decision_list.append((group_idx, "accept", group_total_time))
                        else:
                            print("Mises à jour du groupe rejetées. Rollback vers le safe point.")
                            self.server.model.load_state_dict(safe_model)
                            self.server.optimizer.load_state_dict(safe_optimizer)
                            restored_acc = self.server.evaluate(self.test_loader)
                            print(f"Accuracy après rollback : {restored_acc}%")
                            self.server.total_waste_compute_time += group_total_time
                            group_decision_list.append((group_idx, "rollback", group_total_time))
                        group_updates = []
                        group_compute_times = []
                        group_batch_count = 0
                        group_idx += 1

            # Affecter les workers disponibles aux mini-batches non traités
            available_workers = [w for w in self.workers if w.is_available(self.global_time) and w not in self.in_progress_workers]
            for mini_idx in sorted(self.server.current_mini_batches.keys()):
                if mini_idx in self.server.received_gradients and isinstance(self.server.received_gradients[mini_idx], dict):
                    continue
                current_count = len(self.server.received_gradients.get(mini_idx, []))
                while current_count < k and available_workers:
                    worker = available_workers.pop(0)
                    updated_state = copy.deepcopy(self.server.model.state_dict())
                    worker.update_model(updated_state)
                    data, targets = self.server.current_mini_batches[mini_idx]
                    worker.start_computation(self.global_time, (self.server.current_batch_id, mini_idx), data, targets)
                    self.in_progress_workers.append(worker)
                    current_count += 1

            if self.global_time % eval_interval == 0:
                acc = self.server.evaluate(self.test_loader)
                accuracy_over_time.append(acc)
                time_points.append(self.global_time)

            self.global_time += 1

        # À la fin du cycle, si le groupe en cours n'est pas complet,
        # revenir au safe point.
        if group_batch_count > 0 and group_batch_count < self.group_size:
            print("Cycle incomplet : retour au safe point.")
            self.server.model.load_state_dict(safe_model)
            self.server.optimizer.load_state_dict(safe_optimizer)
            final_acc = safe_acc
        else:
            final_acc = self.server.evaluate(self.test_loader)
        
        print(f"Accuracy finale du cycle : {final_acc:.2f}%")
        plt.figure(figsize=(10, 5))
        plt.plot(time_points, accuracy_over_time, linewidth=2)
        plt.title("Évolution de l'accuracy durant le cycle")
        plt.xlabel("Temps du cycle (steps)")
        plt.ylabel("Accuracy (%)")
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

        # Scatter plot comparatif des groupes
        accepted_groups = [(idx, t) for idx, decision, t in group_decision_list if decision == "accept"]
        rollback_groups = [(idx, t) for idx, decision, t in group_decision_list if decision == "rollback"]

        if accepted_groups:
            idxs_accept, times_accept = zip(*accepted_groups)
        else:
            idxs_accept, times_accept = [], []
        if rollback_groups:
            idxs_rollback, times_rollback = zip(*rollback_groups)
        else:
            idxs_rollback, times_rollback = [], []

        plt.figure(figsize=(10,6))
        plt.scatter(idxs_accept, times_accept, color="blue", alpha=0.7,
                    label="Useful Computing (Groupes acceptés)", s=100)
        plt.scatter(idxs_rollback, times_rollback, color="orange", alpha=0.7,
                    label="Waste Computing (Groupes rollback)", s=100)
        plt.title("Computing Time par Groupe")
        plt.xlabel("Indice du groupe")
        plt.ylabel("Computing Time total par groupe")
        plt.legend()
        plt.show()

        return final_acc

    def plot_worker_availability(self):
        """
        Affiche, pour chaque instant de temps, le nombre total de workers honnêtes (bleu)
        et Byzantins (rouge) disponibles.
        """

        num_workers = len(self.workers)
        fig_height = max(6, min(0.05 * num_workers, 20))
        fig, ax = plt.subplots(figsize=(12, fig_height))
        for worker in self.workers:
            color = "tab:red" if isinstance(worker, ByzantineWorker) else "tab:blue"
            for (start, end) in worker.availability_periods:
                ax.broken_barh([(start, end - start)], (worker.worker_id - 0.4, 0.8), facecolors=color)
        ax.set_xlabel("Temps", fontsize=12)
        ax.set_ylabel("ID du Worker", fontsize=12)
        ax.set_title("Disponibilité des Workers (bleu: honnêtes, rouge: byzantins)", fontsize=14)
        ax.set_xlim(0, self.total_time_steps)
        max_worker_id = max(worker.worker_id for worker in self.workers)
        ax.set_ylim(0, max_worker_id + 1)
        step = max(1, num_workers // 40)
        ax.set_yticks(list(range(1, max_worker_id + 1, step)))
        ax.grid(True, axis='y', linestyle='--', alpha=0.2)
        from matplotlib.patches import Patch
        legend_elements = [
            Patch(facecolor='tab:blue', label='Honnête'),
            Patch(facecolor='tab:red', label='Byzantin')
        ]
        ax.legend(handles=legend_elements, loc='upper right')
        plt.tight_layout()
        plt.show()


        # Initialiser deux tableaux pour compter séparément
        avail_honest = [0] * self.total_time_steps
        avail_byz   = [0] * self.total_time_steps

        for worker in self.workers:
            target = avail_byz if worker.is_byzantine else avail_honest
            for start, end in worker.availability_periods:
                for t in range(start, min(end, self.total_time_steps)):
                    target[t] += 1

        times = range(self.total_time_steps)
        plt.figure(figsize=(12, 6))
        plt.plot(times, avail_honest, label="Honest workers", color="blue", linewidth=2)
        plt.plot(times, avail_byz,   label="Byzantine workers", color="red",  linewidth=2)
        plt.xlabel("Temps", fontsize=12)
        plt.ylabel("Nombre de workers disponibles", fontsize=12)
        plt.title("Disponibilité cumulée des workers au cours du temps", fontsize=14)
        plt.legend(loc="upper right", fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()


# ------------------------------------------------------------------------------
# run_experiment : Pour chaque cycle, on recalcule une liste d'IDs byzantins de manière aléatoire.
def run_experiment(num_cycles=2, num_runs=1, steps_per_cycle=1000, byzantine_ratio=0.0,
                   aggregation_strategy='trimmed_mean', preagg=None):
    accuracy_list = []
    num_worker = 200
    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Normalize((0.1307,), (0.3081,))])
    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
    
    for run in range(num_runs):
        server = Server(train_dataset, batch_size=640, mini_batch_size=64, verbose=False,
                        aggregation_strategy=aggregation_strategy, preagg=preagg)
        cycle_accuracies = []
        for cycle in range(num_cycles):
            print(f"\n===== Cycle {cycle+1} / {num_cycles} =====")
            # Ici, on calcule à chaque cycle une nouvelle liste aléatoire d'IDs byzantins.
            byzantine_indices_cycle = set(random.sample(range(1, num_worker+1),
                                                         int(num_worker * byzantine_ratio)))
            workers = create_workers(num_worker, byzantine_indices_cycle, steps_per_cycle, server)
            simulator = SafePointSimulator(server, workers, test_loader, total_time_steps=steps_per_cycle, group_size=3)
            cycle_acc = simulator.run(verbose=False, eval_interval=20)
            cycle_accuracies.append(cycle_acc)
            server.report_compute_metrics()
        final_acc = cycle_accuracies[-1]
        print(f"Run final - Accuracy après {num_cycles} cycles : {final_acc:.2f}%")
        accuracy_list.append(final_acc)
    overall_acc = np.mean(accuracy_list)
    print(f"\nAccuracy moyenne sur tous les runs : {overall_acc:.2f}%")
    return overall_acc

# ------------------------------------------------------------------------------
# Main
if __name__ == "__main__":
    preagg_methods = [None]
    aggregator_methods = ["average"]
    byzantine_ratios = [0.0, 0.1, 0.2, 0.3, 0.4]
    num_runs = 1
    num_cycles = 2
    steps_per_cycle = 1000
    for preagg in preagg_methods:
        plt.figure(figsize=(10,7))
        for agg in aggregator_methods:
            results = []
            for ratio in byzantine_ratios:
                acc = run_experiment(num_cycles=num_cycles, num_runs=num_runs, steps_per_cycle=steps_per_cycle,
                                     byzantine_ratio=ratio, aggregation_strategy=agg, preagg=preagg)
                results.append(acc)
                method_name = preagg if preagg is not None else "NoPreAgg"
                print(f"PreAgg: {method_name}, Aggregator: {agg}, Byzantine ratio: {ratio*100:.0f}%, Accuracy: {acc:.2f}%")
            plt.plot([r*100 for r in byzantine_ratios], results, marker='o', linewidth=2, markersize=8, label=agg)
        title = f"Pre-aggregation: {preagg if preagg is not None else 'None'}"
        plt.xlabel("Taux de workers byzantins (%)", fontsize=14)
        plt.ylabel("Accuracy moyenne (%)", fontsize=14)
        plt.title(title, fontsize=16)
        plt.legend(title="Aggregators", fontsize=12, title_fontsize=13, loc="best")
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.tight_layout()
        plt.show()
# Out:
# ===== Cycle 1 / 2 =====
# SafePoint initial - Accuracy: 10.49%
# Temps (22) Full batch 1 traité — Performance = 19.9%
# Temps (31) Full batch 2 traité — Performance = 25.23%
# Temps (38) Full batch 3 traité — Performance = 46.62%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (44) Full batch 4 traité — Performance = 58.18%
# Temps (54) Full batch 5 traité — Performance = 77.94%
# Temps (64) Full batch 6 traité — Performance = 81.67%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (77) Full batch 7 traité — Performance = 80.88%
# Temps (86) Full batch 8 traité — Performance = 81.21%
# Temps (92) Full batch 9 traité — Performance = 86.74%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 81.67%
# Temps (96) Full batch 10 traité — Performance = 79.97%
# Temps (100) Full batch 11 traité — Performance = 83.46%
# Temps (104) Full batch 12 traité — Performance = 76.15%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 81.67%
# Temps (108) Full batch 13 traité — Performance = 74.9%
# Temps (112) Full batch 14 traité — Performance = 82.22%
# Temps (117) Full batch 15 traité — Performance = 89.27%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (121) Full batch 16 traité — Performance = 87.96%
# Temps (128) Full batch 17 traité — Performance = 88.52%
# Temps (134) Full batch 18 traité — Performance = 90.14%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 89.27%
# Temps (139) Full batch 19 traité — Performance = 87.55%
# Temps (143) Full batch 20 traité — Performance = 88.81%
# Temps (147) Full batch 21 traité — Performance = 90.87%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 89.27%
# Temps (151) Full batch 22 traité — Performance = 90.4%
# Temps (155) Full batch 23 traité — Performance = 90.37%
# Temps (159) Full batch 24 traité — Performance = 91.99%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (163) Full batch 25 traité — Performance = 92.34%
# Temps (167) Full batch 26 traité — Performance = 92.56%
# Temps (171) Full batch 27 traité — Performance = 92.93%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (175) Full batch 28 traité — Performance = 93.9%
# Temps (179) Full batch 29 traité — Performance = 94.66%
# Temps (183) Full batch 30 traité — Performance = 95.1%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (188) Full batch 31 traité — Performance = 94.74%
# Temps (192) Full batch 32 traité — Performance = 94.74%
# Temps (196) Full batch 33 traité — Performance = 95.39%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (200) Full batch 34 traité — Performance = 95.84%
# Temps (204) Full batch 35 traité — Performance = 95.68%
# Temps (209) Full batch 36 traité — Performance = 96.09%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (213) Full batch 37 traité — Performance = 96.14%
# Temps (217) Full batch 38 traité — Performance = 96.02%
# Temps (222) Full batch 39 traité — Performance = 95.98%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (226) Full batch 40 traité — Performance = 96.15%
# Temps (230) Full batch 41 traité — Performance = 96.11%
# Temps (234) Full batch 42 traité — Performance = 96.04%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (239) Full batch 43 traité — Performance = 96.31%
# Temps (244) Full batch 44 traité — Performance = 96.19%
# Temps (249) Full batch 45 traité — Performance = 95.81%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (254) Full batch 46 traité — Performance = 96.34%
# Temps (259) Full batch 47 traité — Performance = 96.24%
# Temps (264) Full batch 48 traité — Performance = 96.03%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (268) Full batch 49 traité — Performance = 96.28%
# Temps (272) Full batch 50 traité — Performance = 96.1%
# Temps (276) Full batch 51 traité — Performance = 95.8%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (280) Full batch 52 traité — Performance = 96.42%
# Temps (285) Full batch 53 traité — Performance = 96.29%
# Temps (289) Full batch 54 traité — Performance = 96.06%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (297) Full batch 55 traité — Performance = 96.36%
# Temps (302) Full batch 56 traité — Performance = 95.98%
# Temps (307) Full batch 57 traité — Performance = 95.64%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (315) Full batch 58 traité — Performance = 96.26%
# Temps (320) Full batch 59 traité — Performance = 96.08%
# Temps (328) Full batch 60 traité — Performance = 95.97%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (335) Full batch 61 traité — Performance = 96.4%
# Temps (341) Full batch 62 traité — Performance = 96.33%
# Temps (346) Full batch 63 traité — Performance = 95.84%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (354) Full batch 64 traité — Performance = 96.18%
# Temps (359) Full batch 65 traité — Performance = 95.9%
# Temps (363) Full batch 66 traité — Performance = 95.47%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (367) Full batch 67 traité — Performance = 96.25%
# Temps (375) Full batch 68 traité — Performance = 95.91%
# Temps (384) Full batch 69 traité — Performance = 95.62%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (393) Full batch 70 traité — Performance = 96.06%
# Temps (398) Full batch 71 traité — Performance = 95.16%
# Temps (406) Full batch 72 traité — Performance = 95.18%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.09%
# Temps (411) Full batch 73 traité — Performance = 96.48%
# Temps (416) Full batch 74 traité — Performance = 96.54%
# Temps (421) Full batch 75 traité — Performance = 96.47%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (425) Full batch 76 traité — Performance = 96.53%
# Temps (429) Full batch 77 traité — Performance = 96.79%
# Temps (433) Full batch 78 traité — Performance = 97.1%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (438) Full batch 79 traité — Performance = 97.1%
# Temps (443) Full batch 80 traité — Performance = 97.26%
# Temps (447) Full batch 81 traité — Performance = 97.28%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (451) Full batch 82 traité — Performance = 97.28%
# Temps (455) Full batch 83 traité — Performance = 97.2%
# Temps (459) Full batch 84 traité — Performance = 97.15%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (463) Full batch 85 traité — Performance = 97.2%
# Temps (467) Full batch 86 traité — Performance = 97.11%
# Temps (471) Full batch 87 traité — Performance = 97.09%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (475) Full batch 88 traité — Performance = 97.33%
# Temps (479) Full batch 89 traité — Performance = 97.03%
# Temps (483) Full batch 90 traité — Performance = 96.9%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (487) Full batch 91 traité — Performance = 97.47%
# Temps (492) Full batch 92 traité — Performance = 97.25%
# Temps (497) Full batch 93 traité — Performance = 96.95%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (501) Full batch 94 traité — Performance = 97.45%
# Temps (505) Full batch 95 traité — Performance = 97.22%
# Temps (509) Full batch 96 traité — Performance = 97.25%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (513) Full batch 97 traité — Performance = 97.44%
# Temps (518) Full batch 98 traité — Performance = 97.05%
# Temps (522) Full batch 99 traité — Performance = 97.01%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (526) Full batch 100 traité — Performance = 97.28%
# Temps (530) Full batch 101 traité — Performance = 96.95%
# Temps (534) Full batch 102 traité — Performance = 97.04%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (539) Full batch 103 traité — Performance = 97.46%
# Temps (543) Full batch 104 traité — Performance = 97.09%
# Temps (547) Full batch 105 traité — Performance = 96.95%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (552) Full batch 106 traité — Performance = 97.39%
# Temps (557) Full batch 107 traité — Performance = 97.15%
# Temps (563) Full batch 108 traité — Performance = 96.93%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (568) Full batch 109 traité — Performance = 97.38%
# Temps (576) Full batch 110 traité — Performance = 97.13%
# Temps (581) Full batch 111 traité — Performance = 97.0%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (587) Full batch 112 traité — Performance = 97.4%
# Temps (594) Full batch 113 traité — Performance = 97.22%
# Temps (602) Full batch 114 traité — Performance = 96.95%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (610) Full batch 115 traité — Performance = 97.35%
# Temps (618) Full batch 116 traité — Performance = 97.07%
# Temps (626) Full batch 117 traité — Performance = 96.97%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (634) Full batch 118 traité — Performance = 97.39%
# Temps (642) Full batch 119 traité — Performance = 97.15%
# Temps (647) Full batch 120 traité — Performance = 96.93%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (652) Full batch 121 traité — Performance = 97.47%
# Temps (657) Full batch 122 traité — Performance = 97.24%
# Temps (662) Full batch 123 traité — Performance = 97.06%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (667) Full batch 124 traité — Performance = 97.3%
# Temps (672) Full batch 125 traité — Performance = 97.17%
# Temps (676) Full batch 126 traité — Performance = 97.14%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (680) Full batch 127 traité — Performance = 97.25%
# Temps (684) Full batch 128 traité — Performance = 96.86%
# Temps (688) Full batch 129 traité — Performance = 96.86%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (692) Full batch 130 traité — Performance = 97.51%
# Temps (696) Full batch 131 traité — Performance = 97.35%
# Temps (701) Full batch 132 traité — Performance = 97.26%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (706) Full batch 133 traité — Performance = 97.22%
# Temps (712) Full batch 134 traité — Performance = 96.66%
# Temps (716) Full batch 135 traité — Performance = 97.02%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (720) Full batch 136 traité — Performance = 97.39%
# Temps (724) Full batch 137 traité — Performance = 97.39%
# Temps (729) Full batch 138 traité — Performance = 97.21%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (733) Full batch 139 traité — Performance = 96.95%
# Temps (737) Full batch 140 traité — Performance = 96.26%
# Temps (741) Full batch 141 traité — Performance = 97.14%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (745) Full batch 142 traité — Performance = 96.81%
# Temps (750) Full batch 143 traité — Performance = 97.17%
# Temps (755) Full batch 144 traité — Performance = 97.21%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.28%
# Temps (760) Full batch 145 traité — Performance = 97.15%
# Temps (765) Full batch 146 traité — Performance = 97.08%
# Temps (770) Full batch 147 traité — Performance = 97.31%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (774) Full batch 148 traité — Performance = 97.35%
# Temps (778) Full batch 149 traité — Performance = 97.47%
# Temps (783) Full batch 150 traité — Performance = 97.51%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (787) Full batch 151 traité — Performance = 97.58%
# Temps (791) Full batch 152 traité — Performance = 97.54%
# Temps (795) Full batch 153 traité — Performance = 97.57%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (799) Full batch 154 traité — Performance = 97.57%
# Temps (803) Full batch 155 traité — Performance = 97.23%
# Temps (807) Full batch 156 traité — Performance = 97.38%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (811) Full batch 157 traité — Performance = 97.64%
# Temps (816) Full batch 158 traité — Performance = 97.46%
# Temps (820) Full batch 159 traité — Performance = 97.19%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (825) Full batch 160 traité — Performance = 97.71%
# Temps (829) Full batch 161 traité — Performance = 97.77%
# Temps (833) Full batch 162 traité — Performance = 97.42%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (837) Full batch 163 traité — Performance = 97.76%
# Temps (841) Full batch 164 traité — Performance = 97.35%
# Temps (845) Full batch 165 traité — Performance = 97.11%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (849) Full batch 166 traité — Performance = 97.77%
# Temps (854) Full batch 167 traité — Performance = 97.67%
# Temps (859) Full batch 168 traité — Performance = 97.59%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (863) Full batch 169 traité — Performance = 97.73%
# Temps (868) Full batch 170 traité — Performance = 97.59%
# Temps (872) Full batch 171 traité — Performance = 97.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (876) Full batch 172 traité — Performance = 97.76%
# Temps (881) Full batch 173 traité — Performance = 97.61%
# Temps (887) Full batch 174 traité — Performance = 97.4%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (891) Full batch 175 traité — Performance = 97.71%
# Temps (895) Full batch 176 traité — Performance = 97.63%
# Temps (903) Full batch 177 traité — Performance = 97.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (908) Full batch 178 traité — Performance = 97.67%
# Temps (913) Full batch 179 traité — Performance = 96.66%
# Temps (921) Full batch 180 traité — Performance = 96.5%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (926) Full batch 181 traité — Performance = 97.65%
# Temps (933) Full batch 182 traité — Performance = 97.53%
# Temps (938) Full batch 183 traité — Performance = 97.33%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (946) Full batch 184 traité — Performance = 97.74%
# Temps (958) Full batch 185 traité — Performance = 97.62%
# Temps (982) Full batch 186 traité — Performance = 97.44%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Accuracy finale du cycle : 97.51%
# 📊 Rapport de temps de calcul :
# - Temps brut total : 5533
# - Temps utile        : 1094
# - Temps gaspillé     : 4412
# - Taux de gaspillage : 79.74%
# ===== Cycle 2 / 2 =====
# SafePoint initial - Accuracy: 97.51%
# Temps (36) Full batch 188 traité — Performance = 97.6%
# Temps (53) Full batch 189 traité — Performance = 97.13%
# Temps (63) Full batch 190 traité — Performance = 97.07%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (69) Full batch 191 traité — Performance = 97.66%
# Temps (75) Full batch 192 traité — Performance = 97.43%
# Temps (81) Full batch 193 traité — Performance = 97.5%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (86) Full batch 194 traité — Performance = 97.72%
# Temps (90) Full batch 195 traité — Performance = 97.45%
# Temps (94) Full batch 196 traité — Performance = 97.37%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (98) Full batch 197 traité — Performance = 97.75%
# Temps (102) Full batch 198 traité — Performance = 97.45%
# Temps (107) Full batch 199 traité — Performance = 97.39%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (112) Full batch 200 traité — Performance = 97.73%
# Temps (119) Full batch 201 traité — Performance = 97.58%
# Temps (123) Full batch 202 traité — Performance = 97.43%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (128) Full batch 203 traité — Performance = 97.65%
# Temps (132) Full batch 204 traité — Performance = 97.22%
# Temps (136) Full batch 205 traité — Performance = 97.55%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (140) Full batch 206 traité — Performance = 97.52%
# Temps (145) Full batch 207 traité — Performance = 97.36%
# Temps (150) Full batch 208 traité — Performance = 96.95%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (155) Full batch 209 traité — Performance = 97.48%
# Temps (160) Full batch 210 traité — Performance = 96.49%
# Temps (164) Full batch 211 traité — Performance = 96.74%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (168) Full batch 212 traité — Performance = 97.61%
# Temps (173) Full batch 213 traité — Performance = 97.27%
# Temps (178) Full batch 214 traité — Performance = 96.85%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (183) Full batch 215 traité — Performance = 97.57%
# Temps (188) Full batch 216 traité — Performance = 97.32%
# Temps (193) Full batch 217 traité — Performance = 97.19%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (198) Full batch 218 traité — Performance = 97.68%
# Temps (202) Full batch 219 traité — Performance = 97.57%
# Temps (209) Full batch 220 traité — Performance = 96.84%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (213) Full batch 221 traité — Performance = 97.6%
# Temps (217) Full batch 222 traité — Performance = 97.43%
# Temps (221) Full batch 223 traité — Performance = 97.35%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.51%
# Temps (225) Full batch 224 traité — Performance = 97.65%
# Temps (229) Full batch 225 traité — Performance = 97.66%
# Temps (233) Full batch 226 traité — Performance = 97.65%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (238) Full batch 227 traité — Performance = 97.83%
# Temps (242) Full batch 228 traité — Performance = 97.87%
# Temps (246) Full batch 229 traité — Performance = 97.57%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (250) Full batch 230 traité — Performance = 97.8%
# Temps (255) Full batch 231 traité — Performance = 97.61%
# Temps (259) Full batch 232 traité — Performance = 97.48%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (263) Full batch 233 traité — Performance = 97.86%
# Temps (268) Full batch 234 traité — Performance = 97.34%
# Temps (273) Full batch 235 traité — Performance = 97.49%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (278) Full batch 236 traité — Performance = 97.65%
# Temps (283) Full batch 237 traité — Performance = 97.21%
# Temps (287) Full batch 238 traité — Performance = 97.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (291) Full batch 239 traité — Performance = 97.65%
# Temps (295) Full batch 240 traité — Performance = 96.71%
# Temps (299) Full batch 241 traité — Performance = 96.9%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (303) Full batch 242 traité — Performance = 97.73%
# Temps (309) Full batch 243 traité — Performance = 97.59%
# Temps (313) Full batch 244 traité — Performance = 97.42%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (318) Full batch 245 traité — Performance = 98.05%
# Temps (326) Full batch 246 traité — Performance = 97.44%
# Temps (331) Full batch 247 traité — Performance = 97.27%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (339) Full batch 248 traité — Performance = 97.99%
# Temps (347) Full batch 249 traité — Performance = 97.92%
# Temps (355) Full batch 250 traité — Performance = 97.63%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (364) Full batch 251 traité — Performance = 97.96%
# Temps (372) Full batch 252 traité — Performance = 97.5%
# Temps (377) Full batch 253 traité — Performance = 97.18%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (381) Full batch 254 traité — Performance = 97.93%
# Temps (386) Full batch 255 traité — Performance = 97.84%
# Temps (393) Full batch 256 traité — Performance = 97.57%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (398) Full batch 257 traité — Performance = 97.93%
# Temps (407) Full batch 258 traité — Performance = 97.86%
# Temps (414) Full batch 259 traité — Performance = 97.54%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (419) Full batch 260 traité — Performance = 98.04%
# Temps (424) Full batch 261 traité — Performance = 97.71%
# Temps (428) Full batch 262 traité — Performance = 97.64%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (433) Full batch 263 traité — Performance = 98.02%
# Temps (437) Full batch 264 traité — Performance = 98.05%
# Temps (442) Full batch 265 traité — Performance = 97.65%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (446) Full batch 266 traité — Performance = 97.94%
# Temps (451) Full batch 267 traité — Performance = 97.39%
# Temps (456) Full batch 268 traité — Performance = 96.81%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (461) Full batch 269 traité — Performance = 98.0%
# Temps (465) Full batch 270 traité — Performance = 97.9%
# Temps (469) Full batch 271 traité — Performance = 97.59%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (473) Full batch 272 traité — Performance = 97.92%
# Temps (477) Full batch 273 traité — Performance = 97.78%
# Temps (482) Full batch 274 traité — Performance = 97.54%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (487) Full batch 275 traité — Performance = 98.02%
# Temps (492) Full batch 276 traité — Performance = 97.87%
# Temps (496) Full batch 277 traité — Performance = 97.63%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (500) Full batch 278 traité — Performance = 97.94%
# Temps (505) Full batch 279 traité — Performance = 97.45%
# Temps (509) Full batch 280 traité — Performance = 97.18%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (514) Full batch 281 traité — Performance = 98.08%
# Temps (519) Full batch 282 traité — Performance = 97.83%
# Temps (523) Full batch 283 traité — Performance = 97.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (528) Full batch 284 traité — Performance = 97.84%
# Temps (532) Full batch 285 traité — Performance = 97.66%
# Temps (536) Full batch 286 traité — Performance = 97.58%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (541) Full batch 287 traité — Performance = 97.88%
# Temps (546) Full batch 288 traité — Performance = 97.72%
# Temps (551) Full batch 289 traité — Performance = 97.44%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (556) Full batch 290 traité — Performance = 97.97%
# Temps (561) Full batch 291 traité — Performance = 97.62%
# Temps (566) Full batch 292 traité — Performance = 97.68%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (571) Full batch 293 traité — Performance = 97.95%
# Temps (576) Full batch 294 traité — Performance = 97.81%
# Temps (581) Full batch 295 traité — Performance = 97.37%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (586) Full batch 296 traité — Performance = 98.07%
# Temps (591) Full batch 297 traité — Performance = 97.83%
# Temps (595) Full batch 298 traité — Performance = 97.66%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.65%
# Temps (602) Full batch 299 traité — Performance = 97.89%
# Temps (607) Full batch 300 traité — Performance = 97.91%
# Temps (615) Full batch 301 traité — Performance = 97.68%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (623) Full batch 302 traité — Performance = 97.25%
# Temps (628) Full batch 303 traité — Performance = 97.15%
# Temps (632) Full batch 304 traité — Performance = 97.61%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.68%
# Temps (638) Full batch 305 traité — Performance = 97.69%
# Temps (642) Full batch 306 traité — Performance = 97.7%
# Temps (650) Full batch 307 traité — Performance = 97.75%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (662) Full batch 308 traité — Performance = 97.73%
# Temps (674) Full batch 309 traité — Performance = 97.55%
# Temps (683) Full batch 310 traité — Performance = 97.71%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.75%
# Temps (692) Full batch 311 traité — Performance = 97.8%
# Temps (697) Full batch 312 traité — Performance = 97.83%
# Temps (707) Full batch 313 traité — Performance = 97.64%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.75%
# Temps (712) Full batch 314 traité — Performance = 97.93%
# Temps (719) Full batch 315 traité — Performance = 97.97%
# Temps (727) Full batch 316 traité — Performance = 97.89%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (732) Full batch 317 traité — Performance = 97.92%
# Temps (737) Full batch 318 traité — Performance = 97.98%
# Temps (742) Full batch 319 traité — Performance = 97.86%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.89%
# Temps (747) Full batch 320 traité — Performance = 97.91%
# Temps (752) Full batch 321 traité — Performance = 98.08%
# Temps (757) Full batch 322 traité — Performance = 97.9%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (761) Full batch 323 traité — Performance = 98.13%
# Temps (766) Full batch 324 traité — Performance = 98.01%
# Temps (770) Full batch 325 traité — Performance = 97.52%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.9%
# Temps (774) Full batch 326 traité — Performance = 98.19%
# Temps (778) Full batch 327 traité — Performance = 97.37%
# Temps (782) Full batch 328 traité — Performance = 97.2%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.9%
# Temps (786) Full batch 329 traité — Performance = 98.05%
# Temps (790) Full batch 330 traité — Performance = 97.88%
# Temps (794) Full batch 331 traité — Performance = 97.48%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.9%
# Temps (799) Full batch 332 traité — Performance = 98.11%
# Temps (804) Full batch 333 traité — Performance = 97.59%
# Temps (809) Full batch 334 traité — Performance = 97.95%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.9%
# Temps (814) Full batch 335 traité — Performance = 98.16%
# Temps (819) Full batch 336 traité — Performance = 97.98%
# Temps (824) Full batch 337 traité — Performance = 97.65%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.9%
# Temps (829) Full batch 338 traité — Performance = 98.13%
# Temps (834) Full batch 339 traité — Performance = 97.94%
# Temps (839) Full batch 340 traité — Performance = 98.3%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (844) Full batch 341 traité — Performance = 98.08%
# Temps (848) Full batch 342 traité — Performance = 97.59%
# Temps (852) Full batch 343 traité — Performance = 98.06%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.3%
# Temps (856) Full batch 344 traité — Performance = 98.09%
# Temps (860) Full batch 345 traité — Performance = 97.41%
# Temps (864) Full batch 346 traité — Performance = 97.86%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.3%
# Temps (869) Full batch 347 traité — Performance = 98.32%
# Temps (873) Full batch 348 traité — Performance = 98.38%
# Temps (877) Full batch 349 traité — Performance = 98.32%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (881) Full batch 350 traité — Performance = 98.23%
# Temps (885) Full batch 351 traité — Performance = 98.29%
# Temps (890) Full batch 352 traité — Performance = 98.39%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.32%
# Temps (894) Full batch 353 traité — Performance = 98.26%
# Temps (899) Full batch 354 traité — Performance = 98.41%
# Temps (903) Full batch 355 traité — Performance = 98.61%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (910) Full batch 356 traité — Performance = 98.24%
# Temps (915) Full batch 357 traité — Performance = 98.09%
# Temps (925) Full batch 358 traité — Performance = 98.37%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.61%
# Temps (944) Full batch 359 traité — Performance = 98.18%
# Temps (958) Full batch 360 traité — Performance = 98.01%
# Temps (970) Full batch 361 traité — Performance = 98.22%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.61%
# Temps (979) Full batch 362 traité — Performance = 98.61%
# Temps (997) Full batch 363 traité — Performance = 98.52%
# Cycle incomplet : retour au safe point.
# Accuracy finale du cycle : 98.61%
# 📊 Rapport de temps de calcul :
# - Temps brut total : 10829
# - Temps utile        : 1836
# - Temps gaspillé     : 8914
# - Taux de gaspillage : 82.32%
# Run final - Accuracy après 2 cycles : 98.61%
#
# Accuracy moyenne sur tous les runs : 98.61%
# PreAgg: NoPreAgg, Aggregator: average, Byzantine ratio: 0%, Accuracy: 98.61%
#
# ===== Cycle 1 / 2 =====
# SafePoint initial - Accuracy: 10.31%
# Temps (30) Full batch 1 traité — Performance = 10.1%
# Temps (42) Full batch 2 traité — Performance = 10.1%
# Temps (49) Full batch 3 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (56) Full batch 4 traité — Performance = 10.1%
# Temps (62) Full batch 5 traité — Performance = 10.1%
# Temps (72) Full batch 6 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (82) Full batch 7 traité — Performance = 10.1%
# Temps (87) Full batch 8 traité — Performance = 10.1%
# Temps (92) Full batch 9 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (96) Full batch 10 traité — Performance = 10.1%
# Temps (100) Full batch 11 traité — Performance = 10.1%
# Temps (104) Full batch 12 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (108) Full batch 13 traité — Performance = 10.1%
# Temps (113) Full batch 14 traité — Performance = 10.1%
# Temps (118) Full batch 15 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (123) Full batch 16 traité — Performance = 10.1%
# Temps (128) Full batch 17 traité — Performance = 10.1%
# Temps (133) Full batch 18 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (138) Full batch 19 traité — Performance = 10.1%
# Temps (143) Full batch 20 traité — Performance = 10.1%
# Temps (148) Full batch 21 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (152) Full batch 22 traité — Performance = 10.1%
# Temps (156) Full batch 23 traité — Performance = 10.1%
# Temps (160) Full batch 24 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (164) Full batch 25 traité — Performance = 10.1%
# Temps (169) Full batch 26 traité — Performance = 10.1%
# Temps (174) Full batch 27 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (179) Full batch 28 traité — Performance = 10.1%
# Temps (183) Full batch 29 traité — Performance = 10.1%
# Temps (187) Full batch 30 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (191) Full batch 31 traité — Performance = 10.1%
# Temps (196) Full batch 32 traité — Performance = 10.1%
# Temps (200) Full batch 33 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (204) Full batch 34 traité — Performance = 10.1%
# Temps (208) Full batch 35 traité — Performance = 10.1%
# Temps (213) Full batch 36 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (217) Full batch 37 traité — Performance = 10.1%
# Temps (221) Full batch 38 traité — Performance = 10.1%
# Temps (225) Full batch 39 traité — Performance = 10.1%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (229) Full batch 40 traité — Performance = 11.17%
# Temps (233) Full batch 41 traité — Performance = 19.07%
# Temps (238) Full batch 42 traité — Performance = 10.27%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 10.31%
# Temps (242) Full batch 43 traité — Performance = 27.66%
# Temps (246) Full batch 44 traité — Performance = 20.49%
# Temps (251) Full batch 45 traité — Performance = 66.02%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (255) Full batch 46 traité — Performance = 68.59%
# Temps (259) Full batch 47 traité — Performance = 77.49%
# Temps (264) Full batch 48 traité — Performance = 74.96%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (269) Full batch 49 traité — Performance = 77.18%
# Temps (274) Full batch 50 traité — Performance = 76.19%
# Temps (278) Full batch 51 traité — Performance = 82.92%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (284) Full batch 52 traité — Performance = 85.48%
# Temps (289) Full batch 53 traité — Performance = 84.2%
# Temps (296) Full batch 54 traité — Performance = 87.51%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (301) Full batch 55 traité — Performance = 91.42%
# Temps (306) Full batch 56 traité — Performance = 92.51%
# Temps (311) Full batch 57 traité — Performance = 92.13%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (319) Full batch 58 traité — Performance = 91.92%
# Temps (327) Full batch 59 traité — Performance = 92.17%
# Temps (335) Full batch 60 traité — Performance = 92.88%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (343) Full batch 61 traité — Performance = 93.62%
# Temps (356) Full batch 62 traité — Performance = 94.32%
# Temps (370) Full batch 63 traité — Performance = 94.6%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (379) Full batch 64 traité — Performance = 94.4%
# Temps (391) Full batch 65 traité — Performance = 94.38%
# Temps (399) Full batch 66 traité — Performance = 95.09%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (407) Full batch 67 traité — Performance = 95.51%
# Temps (412) Full batch 68 traité — Performance = 95.67%
# Temps (417) Full batch 69 traité — Performance = 95.72%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (422) Full batch 70 traité — Performance = 95.7%
# Temps (432) Full batch 71 traité — Performance = 95.79%
# Temps (437) Full batch 72 traité — Performance = 95.96%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (442) Full batch 73 traité — Performance = 96.23%
# Temps (447) Full batch 74 traité — Performance = 96.45%
# Temps (452) Full batch 75 traité — Performance = 96.49%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (456) Full batch 76 traité — Performance = 96.59%
# Temps (461) Full batch 77 traité — Performance = 96.72%
# Temps (466) Full batch 78 traité — Performance = 96.88%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (470) Full batch 79 traité — Performance = 96.98%
# Temps (474) Full batch 80 traité — Performance = 97.06%
# Temps (478) Full batch 81 traité — Performance = 96.97%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (483) Full batch 82 traité — Performance = 96.94%
# Temps (488) Full batch 83 traité — Performance = 97.02%
# Temps (492) Full batch 84 traité — Performance = 97.04%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (496) Full batch 85 traité — Performance = 97.06%
# Temps (499) Full batch 86 traité — Performance = 97.11%
# Temps (503) Full batch 87 traité — Performance = 97.22%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (508) Full batch 88 traité — Performance = 97.23%
# Temps (512) Full batch 89 traité — Performance = 97.29%
# Temps (516) Full batch 90 traité — Performance = 97.45%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (520) Full batch 91 traité — Performance = 97.47%
# Temps (524) Full batch 92 traité — Performance = 97.6%
# Temps (529) Full batch 93 traité — Performance = 97.58%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (533) Full batch 94 traité — Performance = 97.5%
# Temps (537) Full batch 95 traité — Performance = 97.49%
# Temps (541) Full batch 96 traité — Performance = 97.53%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.58%
# Temps (545) Full batch 97 traité — Performance = 97.68%
# Temps (549) Full batch 98 traité — Performance = 97.66%
# Temps (553) Full batch 99 traité — Performance = 97.7%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (557) Full batch 100 traité — Performance = 97.81%
# Temps (562) Full batch 101 traité — Performance = 97.87%
# Temps (566) Full batch 102 traité — Performance = 98.01%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (570) Full batch 103 traité — Performance = 98.08%
# Temps (575) Full batch 104 traité — Performance = 98.08%
# Temps (580) Full batch 105 traité — Performance = 98.05%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.01%
# Temps (585) Full batch 106 traité — Performance = 98.11%
# Temps (592) Full batch 107 traité — Performance = 98.05%
# Temps (597) Full batch 108 traité — Performance = 98.09%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.01%
# Temps (605) Full batch 109 traité — Performance = 98.09%
# Temps (610) Full batch 110 traité — Performance = 98.06%
# Temps (619) Full batch 111 traité — Performance = 97.99%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.01%
# Temps (624) Full batch 112 traité — Performance = 98.0%
# Temps (629) Full batch 113 traité — Performance = 98.18%
# Temps (637) Full batch 114 traité — Performance = 98.14%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (645) Full batch 115 traité — Performance = 98.06%
# Temps (653) Full batch 116 traité — Performance = 98.11%
# Temps (664) Full batch 117 traité — Performance = 98.05%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (676) Full batch 118 traité — Performance = 98.12%
# Temps (686) Full batch 119 traité — Performance = 98.2%
# Temps (699) Full batch 120 traité — Performance = 98.12%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (709) Full batch 121 traité — Performance = 98.25%
# Temps (714) Full batch 122 traité — Performance = 98.17%
# Temps (718) Full batch 123 traité — Performance = 97.93%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (724) Full batch 124 traité — Performance = 98.21%
# Temps (728) Full batch 125 traité — Performance = 98.11%
# Temps (732) Full batch 126 traité — Performance = 97.97%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (737) Full batch 127 traité — Performance = 98.25%
# Temps (742) Full batch 128 traité — Performance = 98.22%
# Temps (747) Full batch 129 traité — Performance = 98.2%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (752) Full batch 130 traité — Performance = 98.29%
# Temps (757) Full batch 131 traité — Performance = 98.27%
# Temps (762) Full batch 132 traité — Performance = 98.08%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (766) Full batch 133 traité — Performance = 98.16%
# Temps (770) Full batch 134 traité — Performance = 97.98%
# Temps (775) Full batch 135 traité — Performance = 97.74%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (780) Full batch 136 traité — Performance = 98.19%
# Temps (785) Full batch 137 traité — Performance = 98.03%
# Temps (789) Full batch 138 traité — Performance = 98.01%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (793) Full batch 139 traité — Performance = 98.26%
# Temps (797) Full batch 140 traité — Performance = 98.24%
# Temps (802) Full batch 141 traité — Performance = 98.19%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (807) Full batch 142 traité — Performance = 98.07%
# Temps (812) Full batch 143 traité — Performance = 96.39%
# Temps (817) Full batch 144 traité — Performance = 84.74%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (821) Full batch 145 traité — Performance = 97.52%
# Temps (826) Full batch 146 traité — Performance = 90.22%
# Temps (831) Full batch 147 traité — Performance = 38.91%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (835) Full batch 148 traité — Performance = 97.53%
# Temps (839) Full batch 149 traité — Performance = 90.54%
# Temps (844) Full batch 150 traité — Performance = 40.43%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (849) Full batch 151 traité — Performance = 97.53%
# Temps (854) Full batch 152 traité — Performance = 91.11%
# Temps (859) Full batch 153 traité — Performance = 43.86%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (864) Full batch 154 traité — Performance = 97.92%
# Temps (869) Full batch 155 traité — Performance = 93.62%
# Temps (873) Full batch 156 traité — Performance = 47.67%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (879) Full batch 157 traité — Performance = 97.23%
# Temps (884) Full batch 158 traité — Performance = 81.04%
# Temps (889) Full batch 159 traité — Performance = 12.8%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (893) Full batch 160 traité — Performance = 96.65%
# Temps (897) Full batch 161 traité — Performance = 65.54%
# Temps (901) Full batch 162 traité — Performance = 10.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (905) Full batch 163 traité — Performance = 96.49%
# Temps (909) Full batch 164 traité — Performance = 60.57%
# Temps (913) Full batch 165 traité — Performance = 10.28%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (917) Full batch 166 traité — Performance = 96.56%
# Temps (921) Full batch 167 traité — Performance = 66.41%
# Temps (926) Full batch 168 traité — Performance = 10.43%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (930) Full batch 169 traité — Performance = 96.75%
# Temps (936) Full batch 170 traité — Performance = 68.42%
# Temps (940) Full batch 171 traité — Performance = 10.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (946) Full batch 172 traité — Performance = 96.33%
# Temps (953) Full batch 173 traité — Performance = 53.73%
# Temps (962) Full batch 174 traité — Performance = 10.28%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (968) Full batch 175 traité — Performance = 96.38%
# Temps (974) Full batch 176 traité — Performance = 60.22%
# Temps (982) Full batch 177 traité — Performance = 10.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (991) Full batch 178 traité — Performance = 97.24%
# Cycle incomplet : retour au safe point.
# Accuracy finale du cycle : 98.14%
# 📊 Rapport de temps de calcul :
# - Temps brut total : 5284
# - Temps utile        : 1831
# - Temps gaspillé     : 3419
# - Taux de gaspillage : 64.70%
# ===== Cycle 2 / 2 =====
# SafePoint initial - Accuracy: 98.14%
# Temps (13) Full batch 180 traité — Performance = 97.48%
# Temps (23) Full batch 181 traité — Performance = 91.62%
# Temps (38) Full batch 182 traité — Performance = 43.04%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (53) Full batch 183 traité — Performance = 97.13%
# Temps (61) Full batch 184 traité — Performance = 77.63%
# Temps (69) Full batch 185 traité — Performance = 12.33%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (78) Full batch 186 traité — Performance = 97.04%
# Temps (86) Full batch 187 traité — Performance = 78.37%
# Temps (94) Full batch 188 traité — Performance = 12.86%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.14%
# Temps (99) Full batch 189 traité — Performance = 97.2%
# Temps (108) Full batch 190 traité — Performance = 83.37%
# ...
# Temps (878) Full batch 335 traité — Performance = 94.09%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (882) Full batch 336 traité — Performance = 97.48%
# Temps (886) Full batch 337 traité — Performance = 95.44%
# Temps (894) Full batch 338 traité — Performance = 85.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (899) Full batch 339 traité — Performance = 96.63%
# Temps (903) Full batch 340 traité — Performance = 88.97%
# Temps (907) Full batch 341 traité — Performance = 45.46%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (911) Full batch 342 traité — Performance = 96.35%
# Temps (915) Full batch 343 traité — Performance = 85.48%
# Temps (919) Full batch 344 traité — Performance = 36.7%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (923) Full batch 345 traité — Performance = 96.75%
# Temps (931) Full batch 346 traité — Performance = 91.73%
# Temps (939) Full batch 347 traité — Performance = 63.46%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (944) Full batch 348 traité — Performance = 96.26%
# Temps (953) Full batch 349 traité — Performance = 77.32%
# Temps (959) Full batch 350 traité — Performance = 15.21%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (968) Full batch 351 traité — Performance = 94.68%
# Temps (974) Full batch 352 traité — Performance = 53.39%
# Temps (982) Full batch 353 traité — Performance = 10.29%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 98.15%
# Temps (992) Full batch 354 traité — Performance = 94.01%
# Cycle incomplet : retour au safe point.
# Accuracy finale du cycle : 98.15%
# 📊 Rapport de temps de calcul :
# - Temps brut total : 10574
# - Temps utile        : 1917
# - Temps gaspillé     : 8593
# - Taux de gaspillage : 81.27%
# Run final - Accuracy après 2 cycles : 98.15%
#
# Accuracy moyenne sur tous les runs : 98.15%
# PreAgg: NoPreAgg, Aggregator: average, Byzantine ratio: 10%, Accuracy: 98.15%
#
# ===== Cycle 1 / 2 =====
# SafePoint initial - Accuracy: 16.92%
# Temps (12) Full batch 1 traité — Performance = 10.32%
# Temps (24) Full batch 2 traité — Performance = 10.32%
# Temps (41) Full batch 3 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (50) Full batch 4 traité — Performance = 10.32%
# Temps (60) Full batch 5 traité — Performance = 10.32%
# Temps (68) Full batch 6 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (74) Full batch 7 traité — Performance = 10.32%
# Temps (78) Full batch 8 traité — Performance = 10.32%
# Temps (83) Full batch 9 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (88) Full batch 10 traité — Performance = 10.32%
# Temps (93) Full batch 11 traité — Performance = 10.32%
# Temps (97) Full batch 12 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (101) Full batch 13 traité — Performance = 10.32%
# Temps (105) Full batch 14 traité — Performance = 10.32%
# Temps (109) Full batch 15 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (114) Full batch 16 traité — Performance = 10.32%
# Temps (118) Full batch 17 traité — Performance = 10.32%
# Temps (122) Full batch 18 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (126) Full batch 19 traité — Performance = 10.32%
# Temps (130) Full batch 20 traité — Performance = 10.32%
# Temps (135) Full batch 21 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (140) Full batch 22 traité — Performance = 10.32%
# Temps (144) Full batch 23 traité — Performance = 10.32%
# Temps (148) Full batch 24 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (152) Full batch 25 traité — Performance = 10.32%
# Temps (157) Full batch 26 traité — Performance = 10.32%
# Temps (162) Full batch 27 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (166) Full batch 28 traité — Performance = 8.92%
# Temps (170) Full batch 29 traité — Performance = 21.83%
# Temps (174) Full batch 30 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (179) Full batch 31 traité — Performance = 9.8%
# Temps (184) Full batch 32 traité — Performance = 15.88%
# Temps (189) Full batch 33 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (193) Full batch 34 traité — Performance = 10.32%
# Temps (198) Full batch 35 traité — Performance = 10.32%
# Temps (203) Full batch 36 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (207) Full batch 37 traité — Performance = 10.32%
# Temps (211) Full batch 38 traité — Performance = 10.32%
# Temps (215) Full batch 39 traité — Performance = 10.32%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 16.92%
# Temps (220) Full batch 40 traité — Performance = 11.65%
# Temps (224) Full batch 41 traité — Performance = 47.02%
# Temps (229) Full batch 42 traité — Performance = 57.81%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (233) Full batch 43 traité — Performance = 69.96%
# Temps (237) Full batch 44 traité — Performance = 77.27%
# Temps (241) Full batch 45 traité — Performance = 70.24%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (246) Full batch 46 traité — Performance = 86.12%
# Temps (250) Full batch 47 traité — Performance = 80.88%
# Temps (254) Full batch 48 traité — Performance = 87.94%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (258) Full batch 49 traité — Performance = 89.39%
# Temps (262) Full batch 50 traité — Performance = 89.47%
# Temps (267) Full batch 51 traité — Performance = 91.03%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (271) Full batch 52 traité — Performance = 92.61%
# Temps (277) Full batch 53 traité — Performance = 92.35%
# Temps (282) Full batch 54 traité — Performance = 92.43%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 91.03%
# Temps (289) Full batch 55 traité — Performance = 92.5%
# Temps (294) Full batch 56 traité — Performance = 93.11%
# Temps (301) Full batch 57 traité — Performance = 92.65%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (306) Full batch 58 traité — Performance = 93.17%
# Temps (313) Full batch 59 traité — Performance = 93.79%
# Temps (317) Full batch 60 traité — Performance = 94.1%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (323) Full batch 61 traité — Performance = 94.25%
# Temps (332) Full batch 62 traité — Performance = 94.47%
# Temps (342) Full batch 63 traité — Performance = 94.77%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (350) Full batch 64 traité — Performance = 95.14%
# Temps (358) Full batch 65 traité — Performance = 95.44%
# Temps (366) Full batch 66 traité — Performance = 95.62%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (371) Full batch 67 traité — Performance = 95.81%
# Temps (376) Full batch 68 traité — Performance = 95.81%
# Temps (381) Full batch 69 traité — Performance = 95.85%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (386) Full batch 70 traité — Performance = 95.92%
# Temps (391) Full batch 71 traité — Performance = 96.2%
# Temps (396) Full batch 72 traité — Performance = 96.5%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (406) Full batch 73 traité — Performance = 96.3%
# Temps (411) Full batch 74 traité — Performance = 96.23%
# Temps (416) Full batch 75 traité — Performance = 96.21%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.5%
# Temps (421) Full batch 76 traité — Performance = 96.13%
# Temps (425) Full batch 77 traité — Performance = 95.65%
# Temps (429) Full batch 78 traité — Performance = 95.62%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.5%
# Temps (434) Full batch 79 traité — Performance = 96.43%
# Temps (439) Full batch 80 traité — Performance = 96.58%
# Temps (444) Full batch 81 traité — Performance = 96.61%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (448) Full batch 82 traité — Performance = 96.6%
# Temps (454) Full batch 83 traité — Performance = 96.71%
# Temps (459) Full batch 84 traité — Performance = 96.95%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (463) Full batch 85 traité — Performance = 97.02%
# Temps (468) Full batch 86 traité — Performance = 97.1%
# Temps (474) Full batch 87 traité — Performance = 96.91%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 96.95%
# Temps (479) Full batch 88 traité — Performance = 97.06%
# Temps (483) Full batch 89 traité — Performance = 97.11%
# Temps (487) Full batch 90 traité — Performance = 97.17%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (491) Full batch 91 traité — Performance = 97.32%
# Temps (495) Full batch 92 traité — Performance = 97.36%
# Temps (499) Full batch 93 traité — Performance = 97.46%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (503) Full batch 94 traité — Performance = 97.44%
# Temps (507) Full batch 95 traité — Performance = 97.39%
# Temps (511) Full batch 96 traité — Performance = 97.37%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.46%
# Temps (516) Full batch 97 traité — Performance = 97.38%
# Temps (520) Full batch 98 traité — Performance = 97.35%
# Temps (524) Full batch 99 traité — Performance = 97.41%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.46%
# Temps (529) Full batch 100 traité — Performance = 97.57%
# Temps (533) Full batch 101 traité — Performance = 97.69%
# Temps (537) Full batch 102 traité — Performance = 97.74%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (541) Full batch 103 traité — Performance = 97.75%
# Temps (546) Full batch 104 traité — Performance = 97.71%
# Temps (550) Full batch 105 traité — Performance = 97.65%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (554) Full batch 106 traité — Performance = 97.72%
# Temps (559) Full batch 107 traité — Performance = 97.71%
# Temps (564) Full batch 108 traité — Performance = 97.68%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (569) Full batch 109 traité — Performance = 97.77%
# Temps (574) Full batch 110 traité — Performance = 97.51%
# Temps (579) Full batch 111 traité — Performance = 97.45%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (583) Full batch 112 traité — Performance = 97.84%
# Temps (590) Full batch 113 traité — Performance = 97.74%
# Temps (595) Full batch 114 traité — Performance = 97.56%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (600) Full batch 115 traité — Performance = 97.71%
# Temps (605) Full batch 116 traité — Performance = 97.57%
# Temps (612) Full batch 117 traité — Performance = 97.45%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (620) Full batch 118 traité — Performance = 97.62%
# Temps (633) Full batch 119 traité — Performance = 97.56%
# Temps (645) Full batch 120 traité — Performance = 97.59%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (656) Full batch 121 traité — Performance = 97.67%
# Temps (670) Full batch 122 traité — Performance = 97.55%
# Temps (684) Full batch 123 traité — Performance = 97.36%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (690) Full batch 124 traité — Performance = 97.78%
# Temps (696) Full batch 125 traité — Performance = 97.72%
# Temps (700) Full batch 126 traité — Performance = 97.63%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (706) Full batch 127 traité — Performance = 97.75%
# Temps (710) Full batch 128 traité — Performance = 97.63%
# Temps (715) Full batch 129 traité — Performance = 97.58%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (720) Full batch 130 traité — Performance = 97.67%
# Temps (724) Full batch 131 traité — Performance = 97.66%
# Temps (728) Full batch 132 traité — Performance = 97.5%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.74%
# Temps (734) Full batch 133 traité — Performance = 97.7%
# Temps (738) Full batch 134 traité — Performance = 97.78%
# Temps (744) Full batch 135 traité — Performance = 97.79%
# Mises à jour du groupe acceptées. Nouveau safe point établi.
# Temps (749) Full batch 136 traité — Performance = 97.63%
# Temps (754) Full batch 137 traité — Performance = 97.44%
# Temps (759) Full batch 138 traité — Performance = 97.47%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (764) Full batch 139 traité — Performance = 97.84%
# Temps (769) Full batch 140 traité — Performance = 97.74%
# Temps (773) Full batch 141 traité — Performance = 97.7%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (779) Full batch 142 traité — Performance = 97.76%
# Temps (784) Full batch 143 traité — Performance = 97.77%
# Temps (789) Full batch 144 traité — Performance = 97.62%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (794) Full batch 145 traité — Performance = 96.82%
# Temps (802) Full batch 146 traité — Performance = 93.32%
# Temps (807) Full batch 147 traité — Performance = 69.16%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (814) Full batch 148 traité — Performance = 96.14%
# Temps (818) Full batch 149 traité — Performance = 87.53%
# Temps (823) Full batch 150 traité — Performance = 46.31%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (827) Full batch 151 traité — Performance = 96.21%
# Temps (832) Full batch 152 traité — Performance = 88.87%
# Temps (836) Full batch 153 traité — Performance = 45.76%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (840) Full batch 154 traité — Performance = 95.84%
# Temps (845) Full batch 155 traité — Performance = 82.79%
# Temps (849) Full batch 156 traité — Performance = 33.31%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (853) Full batch 157 traité — Performance = 95.53%
# Temps (857) Full batch 158 traité — Performance = 74.74%
# Temps (861) Full batch 159 traité — Performance = 25.89%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (866) Full batch 160 traité — Performance = 95.52%
# Temps (871) Full batch 161 traité — Performance = 74.49%
# Temps (876) Full batch 162 traité — Performance = 23.7%
# Mises à jour du groupe rejetées. Rollback vers le safe point.
# Accuracy après rollback : 97.79%
# Temps (880) Full batch 163 traité — Performance = 95.26%
